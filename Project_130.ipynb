# %% [markdown]
# <a href="https://colab.research.google.com/github/AumKulkarni/Project-130/blob/main/Project_130.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
data_to_load=files.upload()
# Out:
#      <input type="file" id="files-34d45677-6e9e-45c9-839d-5996a854a0ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34d45677-6e9e-45c9-839d-5996a854a0ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import csv
df=pd.read_csv("total_stars.csv")

# %%
df
# Out:
#      Unnamed: 0.1       Star name                 distance  mass  \
# 0               0             Sun              0.000015813     1
# 1               1          Sirius                   0008.6   2.1
# 2               2         Canopus                     0310    15
# 3               3  Alpha Centauri                   0004.4   1.1
# 4               4        Arcturus                     0037   1.1
# ..            ...             ...                      ...   ...
# 175           182             182  2MASS J22282889-4310262  35.0
# 176           226             226           WISE 0410+1502  20.0
# 177           230             230          WISE 0458+6434A  35.9
# 178           231             231          WISE 0458+6434B  35.9
# 179           285             285           WISE 1405+5534  25.3
#
#             radius  Unnamed: 5  Unnamed: 0  Star name.1  distance.1  mass.1  \
# 0                1         NaN         NaN          NaN         NaN     NaN
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Star name', 'distance', 'mass', 'radius', 'Unnamed: 5',
#        'Unnamed: 0', 'Star name.1', 'distance.1', 'mass.1', 'radius.1'],
#       dtype='object')

# %%
df.drop(["Unnamed: 0.1","Unnamed: 5","Unnamed: 0","distance.1","Star name.1","radius.1","mass.1"],axis=1,inplace=True)

# %%
df
# Out:
#           Star name                 distance  mass         radius
# 0               Sun              0.000015813     1              1
# 1            Sirius                   0008.6   2.1           1.71
# 2           Canopus                     0310    15             71
# 3    Alpha Centauri                   0004.4   1.1            1.2
# 4          Arcturus                     0037   1.1             26
# ..              ...                      ...   ...            ...
# 175             182  2MASS J22282889-4310262  35.0  0.00089731272
# 176             226           WISE 0410+1502  20.0  0.00111686796
# 177             230          WISE 0458+6434A  35.9   0.0040092696
# 178             231          WISE 0458+6434B  35.9   0.0036274344
# 179             285           WISE 1405+5534  25.3  0.00082094568
#
# [180 rows x 4 columns]

# %%
final_data=df.dropna()

# %%
final_data
# Out:
#           Star name                 distance  mass         radius
# 0               Sun              0.000015813     1              1
# 1            Sirius                   0008.6   2.1           1.71
# 2           Canopus                     0310    15             71
# 3    Alpha Centauri                   0004.4   1.1            1.2
# 4          Arcturus                     0037   1.1             26
# ..              ...                      ...   ...            ...
# 175             182  2MASS J22282889-4310262  35.0  0.00089731272
# 176             226           WISE 0410+1502  20.0  0.00111686796
# 177             230          WISE 0458+6434A  35.9   0.0040092696
# 178             231          WISE 0458+6434B  35.9   0.0036274344
# 179             285           WISE 1405+5534  25.3  0.00082094568
#
# [179 rows x 4 columns]

# %%
final_data.reset_index(drop=True,inplace=True)

# %%
final_data.to_csv("final_data.csv")
